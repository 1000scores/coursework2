# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torch
from torch import nn
from RTSD import RTSD
from common import *
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
from einops import rearrange
import matplotlib.patches as patches
import tqdm
import neptune.new as neptune
from pytorch_lightning.loggers.neptune import NeptuneLogger
from model50 import *
from model18 import *
# %load_ext autoreload
# %autoreload 2

# %%
ROOT = ''
val_dataset = RTSD(train=False, root_path=f'{ROOT}data/', with_spaces=True)
batch_size = 4
def collate(batch):
    return tuple(zip(*batch))

def test_dataloader():
    return torch.utils.data.DataLoader(val_dataset,
                                    batch_size=batch_size,
                                    collate_fn=collate,
                                    shuffle=True)

# %% [markdown]
# **Testing model with SGD optimizer and resnet50 as backbone**

# %% [markdown]
# ** Testing with spaces **

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.3,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:42, 18.29s/it]Final:
# Recall = 0.6693548387096774
# Precision = 0.5928571428571429
# (0.5928571428571429, 0.6693548387096774, 0.6287878787878788)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.3,
           threshold_intersect = 0.3,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:41, 18.25s/it]Final:
# Recall = 0.6693548387096774
# Precision = 0.5928571428571429
# (0.5928571428571429, 0.6693548387096774, 0.6287878787878788)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.35,
           threshold_intersect = 0.3,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:57, 18.61s/it]Final:
# Recall = 0.6693548387096774
# Precision = 0.6240601503759399
# (0.6240601503759399, 0.6693548387096774, 0.6459143968871595)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.4,
           threshold_intersect = 0.3,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:49, 18.42s/it]Final:
# Recall = 0.6612903225806451
# Precision = 0.6666666666666666
# (0.6666666666666666, 0.6612903225806451, 0.6639676113360323)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.4,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:42, 18.28s/it]Final:
# Recall = 0.6612903225806451
# Precision = 0.6666666666666666
# (0.6666666666666666, 0.6612903225806451, 0.6639676113360323)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.5,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [14:29, 19.33s/it]Final:
# Recall = 0.6451612903225806
# Precision = 0.7079646017699115
# (0.7079646017699115, 0.6451612903225806, 0.6751054852320674)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.6,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [16:56, 22.60s/it]Final:
# Recall = 0.6048387096774194
# Precision = 0.7575757575757576
# (0.7575757575757576, 0.6048387096774194, 0.672645739910314)

# %%
test_model(f'{ROOT}best_models/model50_epochs3.pt',
           test_dataloader(),
           threshold_approve = 0.6,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [14:51, 19.81s/it]Final:
# Recall = 0.6451612903225806
# Precision = 0.7476635514018691
# (0.7476635514018691, 0.6451612903225806, 0.6926406926406926)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.7,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:39, 18.21s/it]Final:
# Recall = 0.5161290322580645
# Precision = 0.7901234567901234
# (0.7901234567901234, 0.5161290322580645, 0.624390243902439)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.8,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:45, 18.35s/it]Final:
# Recall = 0.4838709677419355
# Precision = 0.821917808219178
# (0.821917808219178, 0.4838709677419355, 0.6091370558375634)

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt'
           threshold_approve = 0.9,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:53, 18.51s/it]tp = 54
# fp = 6
# fn = 70
# Final:
# Recall = 0.43548387096774194
# Precision = 0.9
# (0.9, 0.43548387096774194, 0.5869565217391305)

# %%
cnt_bboxes(test_dataloader())
# Out:
# 45it [00:04, 10.11it/s]Num of bboxes = 121

# %%
test_model(f'{ROOT}best_models/resnet50_SGD.pt',
           test_dataloader(),
           threshold_approve = 0.95,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:47, 18.39s/it]Final:
# Recall = 0.3709677419354839
# Precision = 0.9019607843137255
# (0.9019607843137255, 0.3709677419354839, 0.5257142857142857)

# %%
test_model(f'{ROOT}best_models/model50_epochs3.pt',
           test_dataloader(),
           threshold_approve = 0.9,
           threshold_intersect = 0.2,
           device='cpu')
# Out:
# 0it [00:00, ?it/s]batches:  45
# 45it [13:54, 18.55s/it]tp = 76
# fp = 10
# fn = 45
# Final:
# Recall = 0.628099173553719
# Precision = 0.8837209302325582
# (0.8837209302325582, 0.628099173553719, 0.7342995169082126)
